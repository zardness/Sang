# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:85% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:85% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# <font size="6" color="red ">ch01. 파이선 개요 및 환경설정</font>
#
# # 1.마크다운 이란?
# - 코드와 함깨 문서화 할수 있음
# - 다양한 문서화 문법 ex.README.MD
#
# # 2.주피터 노트북 실행 방법
# - Shift+Enter : 포커스된 셀이 실행되고 커서가 다음 셀로 이동
# - alt+enter : 포커스된 셀이 실행되고 다음 셀이 생성한 후 다음 셀로 이동
# - ctlr+Enter : 포커스된 셀이 실행되고 포커스 이동이 없음
# - Enter : 다시 편집 상태로

# %%
# 주석
# 셀 하나하나에 파이선 실행 소스 입력

# %% [markdown]
# # print() 함수를 이용해서 출력
# print ('hello ,World')
# print ("hello\n\n홍길동")

# %%
age = 25
duration = "2"
print(age + int(duration))
print(str(age) + duration)
# view >toggle line number 선택
# Out:
# 27
# 252

# %% [markdown]
# #3.ESC키 누르고 (핫키)
# -dd : 셀삭제
# -b : 윗셀 추가
# -a : 윗셀추가
# -m : 마크다운셀(문서셀)로 변경
# -y : 코드셀(소스셀)로 변경
# -o : 실행결과 접기/펴기(토글)

# %%
# 주피터 노트북에서 cmd명령어
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 0C81-36F7
#
#  C:\ai\source\01_python 디렉터리
#
# 2026-06-23  오전 11:39    <DIR>          .
# 2026-06-22  오후 02:29    <DIR>          ..
# 2026-06-23  오전 10:55    <DIR>          .ipynb_checkpoints
# 2026-06-23  오전 11:39             4,783 ch_01 파이선 개요 및 환경설정.ipynb
#                1개 파일               4,783 바이트
#                3개 디렉터리  164,227,211,264 바이트 남음

# %%
# 주피터 노트북에서 cmd명령어
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 0C81-36F7
#
#  C:\ai\source\01_python 디렉터리
#
# 2026-06-23  오전 11:41    <DIR>          .
# 2026-06-22  오후 02:29    <DIR>          ..
# 2026-06-23  오전 10:55    <DIR>          .ipynb_checkpoints
# 2026-06-23  오전 11:41             5,528 ch_01 파이선 개요 및 환경설정.ipynb
#                1개 파일               5,528 바이트
#                3개 디렉터리  164,227,227,648 바이트 남음
