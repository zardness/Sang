# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:85% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:20pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:20pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:20px;}
</style>
"""))
# Out:
# <style>
# div.container{width:85% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:20pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:20pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:20px;}
# </style>

# %%
f=open('data/ex.txt','w')
print("쓰기 가능한지:",f.writable())
# Out:
# 쓰기 가능한지: True

# %%
with open('data/ex.txt','w')as f:
    f.write('Python is easy.\nPython is smart.\n')

# %%
with open('data/ex.txt','w')as f:
    print('print함수는 파일  출력,화면출력,화면출력\n',file=f)

# %%
with open('data/ex.txt','w',encoding='utf-8')as f:
    f.write('홍길동,30,서울\n')
    f.write('김길동,25,안양\n')
    text_list = ['홍길동,30,서울\n','김길동,25,안양\n']
    for line in text_list:
        f.write(line)
    f.writelines(text_list)

# %%
with open('data/ex.txt','rt',encoding='utf-8')as txtfile:
    line = txtfile.readline()
    while line!='':
        print(line,end='')
        line=txtfile.readline()
# Out:
# 홍길동,30,서울
# 김길동,25,안양
# 홍길동,30,서울
# 김길동,25,안양
# 홍길동,30,서울
# 김길동,25,안양

# %%
with open('data/ex.txt','r',encoding='UTF-8') as txtfile:
    lines = txtfile.readlines()
print(lines)
# Out:
# ['홍길동,30,서울\n', '김길동,25,안양\n', '홍길동,30,서울\n', '김길동,25,안양\n', '홍길동,30,서울\n', '김길동,25,안양\n']

# %%
with open('data/exex.txt','r',encoding='utf-8')as f:
    lines=f.readlines()
for line in lines:
    data = line.strip().split(',')
    name = data[0]
    age = int(data[1].strip())
    email = data[2].strip()
    address = data[3].strip()
    print(f"이름:{name},나이:{age},메일{email},주소{address}")
# Out:
# 이름:홍길동,나이:20,메일kildong@hong.com,주소서울시 관악구
# 이름:홍길숙,나이:25,메일kilsuk1@hong.com,주소서울시 영등포구
# 이름:신길동,나이:30,메일shinkil@hong.com,주소서울시 동작구

# %%
class Member:
    def __init__(self,name,age,email,address):
        self.name=name
        self.age=age
        self.email=email
        self.address=address
    def __str__(self):
        return "{},{},{},{}".format(self.name,
                                   self.age,
                                   self.email,
                                   self.address)
    def __eq__(self,other):
        if isinstance(other,Member):
            return self.__str__()==other.__str__()
        return True
    def as_dict(self):
        return {'name':self.name,'age':self.age,'email':self.email,'address':self.address}
    def as_list(self):
        return [self.name,self.age,self.email,self.address]

# %%
member = Member("홍길동",33,'hong@h.co.kr','신림동')
member2 = Member("홍길동",33,'hong@h.co.kr','신림동')
print(id(member),id(member2))
print(member==member2)
print(member.__eq__(member2))
print(member)
print(member.as_dict())
print(member.__dict__)
print(member.as_list())
# Out:
# 1573585442448 1573585438992
# True
# True
# 홍길동,33,hong@h.co.kr,신림동
# {'name': '홍길동', 'age': 33, 'email': 'hong@h.co.kr', 'address': '신림동'}
# {'name': '홍길동', 'age': 33, 'email': 'hong@h.co.kr', 'address': '신림동'}
# ['홍길동', 33, 'hong@h.co.kr', '신림동']

# %%
member_list = []
member_dict_list = []
with open('data/exex.txt','r',encoding='utf-8') as f:
    lines = f.readlines()
for line in lines:    
    data = line.strip().split(', ')
    name = data[0]
    age = int(data[1])
    email = data[2]
    address = data[3]
    member = Member(name,age,email,address)
    member_list.append(member)
    member_dict_list.append(member.__dict__)

# %%
[member.__str__() for member in member_list]
# Out:
# ['홍길동,20,kildong@hong.com,서울시 관악구',
#  '홍길숙,25,kilsuk1@hong.com,서울시 영등포구',
#  '신길동,30,shinkil@hong.com,서울시 동작구']

# %%
member_dict_list
# Out:
# [{'name': '홍길동', 'age': 20, 'email': 'kildong@hong.com', 'address': '서울시 관악구'},
#  {'name': '홍길숙',
#   'age': 25,
#   'email': 'kilsuk1@hong.com',
#   'address': '서울시 영등포구'},
#  {'name': '신길동', 'age': 30, 'email': 'shinkil@hong.com', 'address': '서울시 동작구'}]
