# %%
name = input("당신의 이름은?")
if name : 
    print(name, '님 환영합니다.')
    print('환영합니다.')
else :
    print('이름을 입력하세요')
# Out:
# 당신의 이름은?홍길동
# 홍길동 님 환영합니다.
# 환영합니다.

# %%
a = int(input('정수를 입력하세요'))
b = int(input('정수를 입력하세요'))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# 정수를 입력하세요10
# 정수를 입력하세요2
# 12
# 8
# 20
# 5.0
# 5
# 0
